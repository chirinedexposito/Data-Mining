# %% [markdown]
# # Projet : Prédiction de Churn Bancaire
#
# Ce notebook sert de script principal pour exécuter les différentes étapes du projet. Chaque étape est implémentée sous forme de module Python que nous allons appeler successivement.

# %% [markdown]
# ## 1. Prétraitement des données

# %%
# !python 01_pretraitement_donnees.py
print("Prétraitement des données terminé.")

# %% [markdown]
# ## 2. Analyse des données

# %%
# !python 02_analyse_donnees.py
print("Analyse des données terminée.")

# %% [markdown]
# ## 3. Feature Engineering

# %%
# !python 03_feature_engineering.py
print("Feature engineering terminé.")

# %% [markdown]
# ## 4. Modélisation avec AutoGluon

# %%
# !python 04_modelisation_autogluon.py
print("Modélisation AutoGluon terminée.")

# %% [markdown]
# ## 5. Analyse des erreurs

# %%
# !python 05_analyse_erreurs.py
print("Analyse des erreurs terminée.")

# %% [markdown]
# ## 6. Nouvelle modélisation avec AutoGluon

# %%
# !python 06_nouvelle_modelisation_autogluon.py
print("Nouvelle modélisation AutoGluon terminée.")

# %% [markdown]
# ## 7. Modélisation avec CatBoost

# %%
# !python 07_modelisation_catboost.py
print("Modélisation CatBoost terminée.")

# %% [markdown]
# ## 8. Modèle Ensemble

# %%
# !python 08_modele_ensemble.py
print("Modèle Ensemble terminé.")
